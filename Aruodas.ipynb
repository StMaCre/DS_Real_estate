# %% [markdown]
# <a href="https://colab.research.google.com/github/StMaCre/Realestate/blob/main/Aruodas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/file.csv")

# %%
print(df)
# Out:
#       Unnamed: 0                            Region       Price    Ares
# 0              0  Senamiestis\nJ. Basanavičiaus g.  7 000 €/m²   60.00
# 1              1           Antakalnis\nSvajonių g.  4 296 €/m²   81.24
# 2              2         Šnipiškės\nDaugėliškio g.  3 311 €/m²   43.79
# 3              3         Naujininkai\nEišiškių pl.  3 341 €/m²   63.00
# 4              4     Naujamiestis\nA. Vivulskio g.  4 030 €/m²   70.72
# ...          ...                               ...         ...     ...
# 1495        1495    Trakų Vokė\nJ. Tiškevičiaus g.  2 028 €/m²    9.42
# 1496        1496           Naujoji Vilnia\nDūmų g.  1 500 €/m²   31.00
# 1497        1497           Šnipiškės\nKalvarijų g.  2 745 €/m²   51.00
# 1498        1498           Burbiškės\nEišiškių pl.  2 857 €/m²   56.00
# 1499        1499        Senamiestis\nVašingtono a.  2 440 €/m²  204.12
#
# [1500 rows x 4 columns]

# %% [markdown]
# # Cleaning the data

# %%
list = []
for row in df["Price"]:
  list.append(row[:-5])

good_list = []
for element in list: 
  good_list.append(int(element.replace(" ", "")))
df["good_price"] = good_list

# %%
sep = '\n'
list_region = []
for row in df["Region"]: 
  list_region.append(row.split(sep, 1)[0])
print(list_region)

df["region_good"] = list_region
# Out:
# ['Senamiestis', 'Antakalnis', 'Šnipiškės', 'Naujininkai', 'Naujamiestis', 'Žvėrynas', 'Aukštieji Paneriai', 'Senamiestis', 'Senamiestis', 'Valakampiai', 'Antavilis', 'Lazdynėliai', 'Pilaitė', 'Tarandė', 'Fabijoniškės', 'Naujamiestis', 'Fabijoniškės', 'Antakalnis', 'Žirmūnai', 'Šiaurės miestelis', 'Žirmūnai', 'Šnipiškės', 'Šiaurės miestelis', 'Šnipiškės', 'Antavilis', 'Senamiestis', 'Senamiestis', 'Lazdynėliai', 'Pašilaičiai', 'Fabijoniškės', 'Senamiestis', 'Naujamiestis', 'Senamiestis', 'Antakalnis', 'Naujamiestis', 'Senamiestis', 'Užupis', 'Antakalnis', 'Grigiškės', 'Žvėrynas', 'Bajorai', 'Lazdynai', 'Baltupiai', 'Žirmūnai', 'Antakalnis', 'Fabijoniškės', 'Žvėrynas', 'Pilaitė', 'Pilaitė', 'Žirmūnai', 'Pašilaičiai', 'Naujamiestis', 'Užupis', 'Šnipiškės', 'Senamiestis', 'Senamiestis', 'Šnipiškės', 'Žirmūnai', 'Pašilaičiai', 'Šnipiškės', 'Antakalnis', 'Naujamiestis', 'Lazdynėliai', 'Lazdynai', 'Lazdynai', 'Pilaitė', 'Šeškinė', 'Naujininkai', 'Naujoji Vilnia', 'Šnipiškės', 'Naujamiestis', 'Lazdynai', 'Šnipiškės', 'Pilaitė', 'Fabijoniškės', 'Senamiestis', 'Naujamiestis', 'Naujamiestis', 'Jeruzalė', 'Gudeliai', 'Šnipiškės', 'Žvėrynas', 'Užupis', 'Užupis', 'Š
Karoliniškės', 'Užupis', 'Naujininkai', 'Justiniškės', 'Fabijoniškės', 'Baltupiai', 'Šnipiškės', 'Senamiestis', 'Šnipiškės', 'Užupis', 'Pašilaičiai', 'Justiniškės', 'Karoliniškės', 'Fabijoniškės', 'Naujamiestis', 'Pašilaičiai', 'Naujamiestis', 'Lazdynai', 'Šeškinė', 'Šnipiškės', 'Pašilaičiai', 'Pašilaičiai', 'Naujamiestis', 'Lazdynėliai', 'Šnipiškės', 'Justiniškės', 'Naujoji Vilnia', 'Žirmūnai', 'Naujoji Vilnia', 'Fabijoniškės', 'Šeškinė', 'Šeškinė', 'Naujoji Vilnia', 'Naujoji Vilnia', 'Žirmūnai', 'Senamiestis', 'Naujoji Vilnia', 'Šeškinė', 'Šeškinė', 'Žirmūnai', 'Vilkpėdė', 'Senamiestis', 'Šnipiškės', 'Karoliniškės', 'Naujininkai', 'Naujininkai', 'Pašilaičiai' ...

# %%
print(df)
# Out:
#       Unnamed: 0                            Region       Price    Ares  \
# 0              0  Senamiestis\nJ. Basanavičiaus g.  7 000 €/m²   60.00
# 1              1           Antakalnis\nSvajonių g.  4 296 €/m²   81.24
# 2              2         Šnipiškės\nDaugėliškio g.  3 311 €/m²   43.79
# 3              3         Naujininkai\nEišiškių pl.  3 341 €/m²   63.00
# 4              4     Naujamiestis\nA. Vivulskio g.  4 030 €/m²   70.72
# ...          ...                               ...         ...     ...
# 1495        1495    Trakų Vokė\nJ. Tiškevičiaus g.  2 028 €/m²    9.42
# 1496        1496           Naujoji Vilnia\nDūmų g.  1 500 €/m²   31.00
# 1497        1497           Šnipiškės\nKalvarijų g.  2 745 €/m²   51.00
# 1498        1498           Burbiškės\nEišiškių pl.  2 857 €/m²   56.00
# 1499        1499        Senamiestis\nVašingtono a.  2 440 €/m²  204.12
#
#       good_price     region_good
# 0           7000     Senamiestis
# 1           4296      Antakalnis
# 2           3311       Šnipiškės
# 3           3341     Naujininkai
# 4           4030    Naujamiestis
# ...          ...             ...
# 1495        2028      Trakų Vokė
# 1496        1500  Naujoji Vilnia
# 1497        2745       Šnipiškės
# 1498        2857       Burbiškės
# 1499        2440     Senamiestis
#
# [1500 rows x 6 columns]

# %% [markdown]
# # How many new houses are available per region?

# %%
houses_region = df["region_good"].value_counts()

# %% [markdown]
# # What is the mean price per region?

# %%
from matplotlib import pyplot as plt

# %%
grouped_region = df.groupby(['region_good'])['good_price'].mean()
region_sorted_price = grouped_region.sort_values(ascending=False)
print(region_sorted_price)
# Out:
# region_good
# Turniškės             6851.000000
# Paupys                5293.000000
# Senamiestis           4516.447917
# Užupis                4228.371429
# Žvėrynas              3654.600000
# Markučiai             3473.571429
# Valakampiai           3450.777778
# Šnipiškės             3364.394495
# Verkiai               3352.250000
# Naujamiestis          3255.081395
# Šiaurės miestelis     3102.285714
# Tarandė               2876.250000
# Lazdynėliai           2852.806452
# Liepkalnis            2797.000000
# Antakalnis            2786.605634
# Bajorai               2780.000000
# Žirmūnai              2756.677419
# Pavilnys              2753.000000
# Pilaitė               2752.340000
# Gudeliai              2741.000000
# Burbiškės             2697.250000
# Baltupiai             2665.500000
# Filaretai             2664.000000
# Santariškės           2584.066667
# Vilkpėdė              2486.913043
# Jeruzalė              2409.476190
# Kalnėnai              2380.666667
# Visoriai              2364.000000
# Pašilaičiai           2341.393939
# Kirtimai              2295.000000
# Dvarčionys            2246.000000
# Žemieji Paneriai      2207.352941
# Justiniškės           2189.191489
# Fabijoniškės          2174.320755
# Balsiai               2136.000000
# Šeškinė               2106.372093
# Naujininkai           2079.686567
# Rasos                 2060.500000
# Viršuliškės           2024.066667
# Karoliniškės          2020.488372
# Lazdynai              1908.611111
# Trakų Vokė            1812.000000
# Naujoji Vilnia        1694.681818
# Grigiškės             1665.176471
# Salininkai            1575.000000
# Paneriai              1409.000000
# Aukštieji Paneriai    1400.400000
# Antavilis             1292.600000
# Name: good_price, dtype: float64

# %%
ax = region_sorted_price.plot.bar(figsize=(18,5))
plt.show()

# %%
ax = houses_region.plot.bar(figsize=(18,5))
plt.show()

# %% [markdown]
# # Availability of the houses / mean price

# %%
frame = { 'mean_price': region_sorted_price, 'number_houses': houses_region}
availability = pd.DataFrame(frame)
avail_sorted = availability.sort_values("mean_price", ascending=False)
print(avail_sorted)
# Out:
#                      mean_price  number_houses
# Turniškės           6851.000000              1
# Paupys              5293.000000              7
# Senamiestis         4516.447917            192
# Užupis              4228.371429             35
# Žvėrynas            3654.600000             50
# Markučiai           3473.571429              7
# Valakampiai         3450.777778              9
# Šnipiškės           3364.394495            109
# Verkiai             3352.250000              4
# Naujamiestis        3255.081395            172
# Šiaurės miestelis   3102.285714             28
# Tarandė             2876.250000              4
# Lazdynėliai         2852.806452             31
# Liepkalnis          2797.000000              3
# Antakalnis          2786.605634             71
# Bajorai             2780.000000              9
# Žirmūnai            2756.677419             93
# Pavilnys            2753.000000              2
# Pilaitė             2752.340000             50
# Gudeliai            2741.000000              2
# Burbiškės           2697.250000              4
# Baltupiai           2665.500000             42
# Filaretai           2664.000000              2
# Santariškės         2584.066667             15
# Vilkpėdė            2486.913043             23
# Jeruzalė            2409.476190             21
# Kalnėnai            2380.666667              3
# Visoriai            2364.000000              4
# Pašilaičiai         2341.393939             99
# Kirtimai            2295.000000              1
# Dvarčionys          2246.000000              1
# Žemieji Paneriai    2207.352941             17
# Justiniškės         2189.191489             47
# Fabijoniškės        2174.320755             53
# Balsiai             2136.000000              3
# Šeškinė             2106.372093             43
# Naujininkai         2079.686567             67
# Rasos               2060.500000              6
# Viršuliškės         2024.066667             15
# Karoliniškės        2020.488372             43
# Lazdynai            1908.611111             36
# Trakų Vokė          1812.000000              2
# Naujoji Vilnia      1694.681818             44
# Grigiškės           1665.176471             17
# Salininkai          1575.000000              1
# Paneriai            1409.000000              2
# Aukštieji Paneriai  1400.400000              5
# Antavilis           1292.600000              5

# %%
availability.plot.scatter("mean_price", "number_houses", figsize=(18,5))
